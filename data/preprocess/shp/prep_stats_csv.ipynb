# %% [markdown]
# ## 4. Prep Statistics CSV
#
#
# Use this notebook to prepare hydrologic statistic attributes for addition to the segments shapefile. The stats are saved to a CSV. These stats are a subset of the full dataset designed for quick display on the webapp via WMS / WFS. Unless otherwise noted, we are providing the ensemble delta between static landcover, multi-model GCM ensemble, RCP 6.0 scenario, 2046-2075 era (projected) and static landcover, multi-model GCM ensemble, historical scenario, 1976-2005 era (historical reference). This ensemble delta (projected GCM ensemble minus historical GCM ensemble mean) is applied to the Maurer observational baseline (1976-2005). For percentage variables, the delta is expressed as a fraction of the Maurer historical value (delta / maurer_hist * 100).
#
#
# ### Which stats?
#
#
# #### Magnitude
#
#
# - `ma99`: Mean Annual Flow
#
#
#   - `ma99_hist`: Mean Annual Flow (static landcover, Maurer model, historical scenario, 1976-2005 era)
#
#
#     - **note: this is for the default map view on the web app**
#
#
#     - statistic units = cfs
#
#
#     - difference units = NA
#
#
#   - `ma99_avg_d`: difference between mean of ensemble `ma99` values and GCM historical ensemble mean
#
#
#   - `ma99_min_d`: difference between minimum of ensemble `ma99` values and GCM historical ensemble mean
#
#
#   - `ma99_max_d`: difference between maximum of ensemble `ma99` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma12`: Mean January Flow
#
#
#   - `ma12_avg_d`: difference between mean of ensemble `ma12` values and GCM historical ensemble mean
#
#
#   - `ma12_min_d`: difference between minimum of ensemble `ma12` values and GCM historical ensemble mean
#
#
#   - `ma12_max_d`: difference between maximum of ensemble `ma12` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma13`: Mean February Flow
#
#
#   - `ma13_avg_d`: difference between mean of ensemble `ma13` values and GCM historical ensemble mean
#
#
#   - `ma13_min_d`: difference between minimum of ensemble `ma13` values and GCM historical ensemble mean
#
#
#   - `ma13_max_d`: difference between maximum of ensemble `ma13` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma14`: Mean March Flow
#
#
#   - `ma14_avg_d`: difference between mean of ensemble `ma14` values and GCM historical ensemble mean
#
#
#   - `ma14_min_d`: difference between minimum of ensemble `ma14` values and GCM historical ensemble mean
#
#
#   - `ma14_max_d`: difference between maximum of ensemble `ma14` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma15`: Mean April Flow
#
#
#   - `ma15_avg_d`: difference between mean of ensemble `ma15` values and GCM historical ensemble mean
#
#
#   - `ma15_min_d`: difference between minimum of ensemble `ma15` values and GCM historical ensemble mean
#
#
#   - `ma15_max_d`: difference between maximum of ensemble `ma15` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma16`: Mean May Flow
#
#
#   - `ma16_avg_d`: difference between mean of ensemble `ma16` values and GCM historical ensemble mean
#
#
#   - `ma16_min_d`: difference between minimum of ensemble `ma16` values and GCM historical ensemble mean
#
#
#   - `ma16_max_d`: difference between maximum of ensemble `ma16` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma17`: Mean June Flow
#
#
#   - `ma17_avg_d`: difference between mean of ensemble `ma17` values and GCM historical ensemble mean
#
#
#   - `ma17_min_d`: difference between minimum of ensemble `ma17` values and GCM historical ensemble mean
#
#
#   - `ma17_max_d`: difference between maximum of ensemble `ma17` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma18`: Mean July Flow
#
#
#   - `ma18_avg_d`: difference between mean of ensemble `ma18` values and GCM historical ensemble mean
#
#
#   - `ma18_min_d`: difference between minimum of ensemble `ma18` values and GCM historical ensemble mean
#
#
#   - `ma18_max_d`: difference between maximum of ensemble `ma18` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma19`: Mean August Flow
#
#
#   - `ma19_avg_d`: difference between mean of ensemble `ma19` values and GCM historical ensemble mean
#
#
#   - `ma19_min_d`: difference between minimum of ensemble `ma19` values and GCM historical ensemble mean
#
#
#   - `ma19_max_d`: difference between maximum of ensemble `ma19` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma20`: Mean September Flow
#
#
#   - `ma20_avg_d`: difference between mean of ensemble `ma20` values and GCM historical ensemble mean
#
#
#   - `ma20_min_d`: difference between minimum of ensemble `ma20` values and GCM historical ensemble mean
#
#
#   - `ma20_max_d`: difference between maximum of ensemble `ma20` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma21`: Mean October Flow
#
#
#   - `ma21_avg_d`: difference between mean of ensemble `ma21` values and GCM historical ensemble mean
#
#
#   - `ma21_min_d`: difference between minimum of ensemble `ma21` values and GCM historical ensemble mean
#
#
#   - `ma21_max_d`: difference between maximum of ensemble `ma21` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma22`: Mean November Flow
#
#
#   - `ma22_avg_d`: difference between mean of ensemble `ma22` values and GCM historical ensemble mean
#
#
#   - `ma22_min_d`: difference between minimum of ensemble `ma22` values and GCM historical ensemble mean
#
#
#   - `ma22_max_d`: difference between maximum of ensemble `ma22` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma23`: Mean December Flow
#
#
#   - `ma23_avg_d`: difference between mean of ensemble `ma23` values and GCM historical ensemble mean
#
#
#   - `ma23_min_d`: difference between minimum of ensemble `ma23` values and GCM historical ensemble mean
#
#
#   - `ma23_max_d`: difference between maximum of ensemble `ma23` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# #### Duration
#
#
# - `dh1`: Annual Maximum Daily Flow
#
#
#   - `dh1_max_d`: difference between maximum of ensemble `dh1` values and GCM historical ensemble mean
#
#
#   - `dh1_min_d`: difference between minimum of ensemble `dh1` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `dl1`: Annual Minimum Daily Flow
#
#
#   - `dl1_max_d`: difference between maximum of ensemble `dl1` values and GCM historical ensemble mean
#
#
#   - `dl1_min_d`: difference between minimum of ensemble `dl1` values and GCM historical ensemble mean
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `dh15`: High Flow Pulse Duration
#
#
#   - `dh15_hist`: High Flow Pulse Duration (static landcover, Maurer model, historical scenario, 1976-2005 era)
#
#
#     - **note: this is for data sentence context**
#
#
#     - statistic units = days per year
#
#
#     - difference units = NA
#
#
#   - `dh15_avg_d`: difference between mean of ensemble `dh15` values and GCM historical ensemble mean
#
#
#   - `dh15_max_d`: difference between maximum of ensemble `dh15` values and GCM historical ensemble mean
#
#
#   - `dh15_min_d`: difference between minimum of ensemble `dh15` values and GCM historical ensemble mean
#
#
#   - statistic units = days per year
#
#
#   - difference units = absolute +/-
#
#
#
#
# - `dl16`: Low Flow Pulse Duration
#
#
#   - `dl16_hist`: Low Flow Pulse Duration (static landcover, Maurer model, historical scenario, 1976-2005 era)
#
#
#     - **note: this is for data sentence context**
#
#
#     - statistic units = days per year
#
#
#     - difference units = NA
#
#
#   - `dl16_avg_d`: difference between mean of ensemble `lh16` values and GCM historical ensemble mean
#
#
#   - `dl16_max_d`: difference between maximum of ensemble `dl16` values and GCM historical ensemble mean
#
#
#   - `dl16_min_d`: difference between minimum of ensemble `dl16` values and GCM historical ensemble mean
#
#
#   - statistic units = days per year
#
#
#   - difference units = absolute +/-
#
#
#
#
# #### Frequency
#
#
# - `fh1`: High Flood Pulse Count
#
#
#   - `fh1_hist`: High Flood Pulse Count (static landcover, Maurer model, historical scenario, 1976-2005 era)
#
#
#     - **note: this is for data sentence context**
#
#
#     - statistic units = events per year
#
#
#     - difference units = NA
#
#
#   - `fh1_avg_d`: difference between mean of ensemble `fh1` values and GCM historical ensemble mean
#
#
#   - `fh1_max_d`: difference between maximum of ensemble `fh1` values and GCM historical ensemble mean
#
#
#   - `fh1_min_d`: difference between minimum of ensemble `fh1` values and GCM historical ensemble mean
#
#
#   - statistic units = events per year
#
#
#   - difference units = absolute +/-
#
#
#
#
# - `fl1`: Low Flood Pulse Count
#
#
#   - `fl1_hist`: Low Flood Pulse Count (static landcover, Maurer model, historical scenario, 1976-2005 era)
#
#
#     - **note: this is for data sentence context**
#
#
#     - statistic units = events per year
#
#
#     - difference units = NA
#
#
#   - `fl1_avg_d`: difference between mean of ensemble `fl1` values and GCM historical ensemble mean
#
#
#   - `fl1_max_d`: difference between maximum of ensemble `fl1` values and GCM historical ensemble mean
#
#
#   - `fl1_min_d`: difference between minimum of ensemble `fl1` values and GCM historical ensemble mean
#
#
#   - statistic units = events per year
#
#
#   - difference units = absolute +/-
#
#
#
#
# #### Timing
#
#
# - `th1`: Julian Date of Annual Maximum
#
#
#   - `th1_avg_d`: difference between mean of ensemble `th1` values and GCM historical ensemble mean
#
#
#   - `th1_min_d`: difference between minimum of ensemble `th1` values and GCM historical ensemble mean
#
#
#   - `th1_max_d`: difference between maximum of ensemble `th1` values and GCM historical ensemble mean
#
#
#   - statistic units = day of year
#
#
#   - difference units = absolute +/-
#
#
#
#
# - `tl1`: Julian Date of Annual Minimum
#
#
#   - `tl1_avg_d`: difference between mean of ensemble `tl1` values and GCM historical ensemble mean
#
#
#   - `tl1_min_d`: difference between minimum of ensemble `tl1` values and GCM historical ensemble mean
#
#
#   - `tl1_max_d`: difference between maximum of ensemble `tl1` values and GCM historical ensemble mean
#
#
#   - statistic units = day of year
#
#
#   - difference units = absolute +/-

# %% [markdown]
# ### Setup

# %%
import xarray as xr
import numpy as np
import ast
import pandas as pd
import random
import json

# %%
vars = {
    "ma12": {
        "var_description": "Mean January flow",
        "stats": ["ma12_min_d", "ma12_avg_d", "ma12_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma12 values and GCM historical ensemble mean",
            "difference between mean of ensemble ma12 values and GCM historical ensemble mean",
            "difference between maximum of ensemble ma12 values and GCM historical ensemble mean"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma13": {
        "var_description": "Mean February flow",
        "stats": ["ma13_min_d", "ma13_avg_d", "ma13_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma13 values and GCM historical ensemble mean",
            "difference between mean of ensemble ma13 values and GCM historical ensemble mean",
            "difference between maximum of ensemble ma13 values and GCM historical ensemble mean"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma14": {
        "var_description": "Mean March flow",
        "stats": ["ma14_min_d", "ma14_avg_d", "ma14_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma14 values and GCM historical ensemble mean",
            "difference between mean of ensemble ma14 values and GCM historical ensemble mean",
            "difference between maximum of ensemble ma14 values and GCM historical ensemble mean"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma15": {
        "var_description": "Mean April flow",
        "stats": ["ma15_min_d", "ma15_avg_d", "ma15_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma15 values and GCM historical ensemble mean",
            "difference between mean of ensemble ma15 values and GCM historical ensemble mean",
            "difference between maximum of ensemble ma15 values and GCM historical ensemble mean"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma16": {
        "var_description": "Mean May flow",
        "stats": ["ma16_min_d", "ma16_avg_d", "ma16_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma16 values and GCM historical ensemble mean",
            "difference between mean of ensemble ma16 values and GCM historical ensemble mean",
            "difference between maximum of ensemble ma16 values and GCM historical ensemble mean"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma17": {
        "var_description": "Mean June flow",
        "stats": ["ma17_min_d", "ma17_avg_d", "ma17_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma17 values and GCM historical ensemble mean",
            "difference between mean of ensemble ma17 values and GCM historical ensemble mean",
            "difference between maximum of ensemble ma17 values and GCM historical ensemble mean"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma18": {
        "var_description": "Mean July flow",
        "stats": ["ma18_min_d", "ma18_avg_d", "ma18_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma18 values and GCM historical ensemble mean",
            "difference between mean of ensemble ma18 values and GCM historical ensemble mean",
            "difference between maximum of ensemble ma18 values and GCM historical ensemble mean"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma19": {
        "var_description": "Mean August flow",
        "stats": ["ma19_min_d", "ma19_avg_d", "ma19_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma19 values and GCM historical ensemble mean",
            "difference between mean of ensemble ma19 values and GCM historical ensemble mean",
            "difference between maximum of ensemble ma19 values and GCM historical ensemble mean"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma20": {
        "var_description": "Mean September flow",
        "stats": ["ma20_min_d", "ma20_avg_d", "ma20_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma20 values and GCM historical ensemble mean",
            "difference between mean of ensemble ma20 values and GCM historical ensemble mean",
            "difference between maximum of ensemble ma20 values and GCM historical ensemble mean"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma21": {
        "var_description": "Mean October flow",
        "stats": ["ma21_min_d", "ma21_avg_d", "ma21_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma21 values and GCM historical ensemble mean",
            "difference between mean of ensemble ma21 values and GCM historical ensemble mean",
            "difference between maximum of ensemble ma21 values and GCM historical ensemble mean"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma22": {
        "var_description": "Mean November flow",
        "stats": ["ma22_min_d", "ma22_avg_d", "ma22_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma22 values and GCM historical ensemble mean",
            "difference between mean of ensemble ma22 values and GCM historical ensemble mean",
            "difference between maximum of ensemble ma22 values and GCM historical ensemble mean"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma23": {
        "var_description": "Mean December flow",
        "stats": ["ma23_min_d", "ma23_avg_d", "ma23_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma23 values and GCM historical ensemble mean",
            "difference between mean of ensemble ma23 values and GCM historical ensemble mean",
            "difference between maximum of ensemble ma23 values and GCM historical ensemble mean"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "dh1": {
        "var_description": "Annual Maximum Daily Flow",
        "stats": ["dh1_min_d", "dh1_max_d"],
        "aggregation": ["minimum", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble dh1 values and GCM historical ensemble mean",
            "difference between maximum of ensemble dh1 values and GCM historical ensemble mean"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "dl1": {
        "var_description": "Annual Minimum Daily Flow",
        "stats": ["dl1_min_d", "dl1_max_d"],
        "aggregation": ["minimum", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble dl1 values and GCM historical ensemble mean",
            "difference between maximum of ensemble dl1 values and GCM historical ensemble mean"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "dh15": {
        "var_description": "High Flow Pulse Duration",
        "stats": ["dh15_min_d", "dh15_avg_d", "dh15_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble dh15 values and GCM historical ensemble mean",
            "difference between mean of ensemble dh15 values and GCM historical ensemble mean",
            "difference between maximum of ensemble dh15 values and GCM historical ensemble mean"
        ],
        "units": "days per year",
        "difference": "absolute"
    },
    "dl16": {
        "var_description": "Low Flow Pulse Duration",
        "stats": ["dl16_min_d", "dl16_avg_d", "dl16_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble dl16 values and GCM historical ensemble mean",
            "difference between mean of ensemble dl16 values and GCM historical ensemble mean",
            "difference between maximum of ensemble dl16 values and GCM historical ensemble mean"
        ],
        "units": "days per year",
        "difference": "absolute"
    },
    "fh1": {
        "var_description": "High Flood Pulse Count",
        "stats": ["fh1_min_d", "fh1_avg_d", "fh1_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble fh1 values and GCM historical ensemble mean",
            "difference between mean of ensemble fh1 values and GCM historical ensemble mean",
            "difference between maximum of ensemble fh1 values and GCM historical ensemble mean"
        ],
        "units": "events per year",
        "difference": "absolute"
    },
    "fl1": {
        "var_description": "Low Flood Pulse Count",
        "stats": ["fl1_min_d", "fl1_avg_d", "fl1_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble fl1 values and GCM historical ensemble mean",
            "difference between mean of ensemble fl1 values and GCM historical ensemble mean",
            "difference between maximum of ensemble fl1 values and GCM historical ensemble mean"
        ],
        "units": "events per year",
        "difference": "absolute"
    },
    "th1": {
        "var_description": "Julian Date of Annual Maximum",
        "stats": ["th1_min_d", "th1_avg_d", "th1_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble th1 values and GCM historical ensemble mean",
            "difference between mean of ensemble th1 values and GCM historical ensemble mean",
            "difference between maximum of ensemble th1 values and GCM historical ensemble mean"
        ],
        "units": "day of year",
        "difference": "absolute"
    },
    "tl1": {
        "var_description": "Julian Date of Annual Minimum",
        "stats": ["tl1_min_d", "tl1_avg_d", "tl1_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble tl1 values and GCM historical ensemble mean",
            "difference between mean of ensemble tl1 values and GCM historical ensemble mean",
            "difference between maximum of ensemble tl1 values and GCM historical ensemble mean"
        ],
        "units": "day of year",
        "difference": "absolute"
    }
    # ma99_* variables handled separately
    # dh15_hist, dl16_hist, fh1_hist, fl1_hist handled separately
}

# %% [markdown]
# Load combined stats file and subset variables.

# %%
ds = xr.open_dataset(
    "/import/beegfs/CMIP6/jdpaul3/hydroviz_data/maurer/nc_stats_fix/seg.nc"
)
ds = ds[list(vars.keys())]

# %% [markdown]
# Decode the dataset dimensions using the encoding attributes.

# %%
for dim in ds.dims:
    if ds[dim].attrs.get("encoding"):
        print(dim, " >>> ", ds[dim].attrs["encoding"])
        encoding_dict = ast.literal_eval(ds[dim].attrs["encoding"])
        decoded_labels = [encoding_dict[k] for k in ds[dim].values.astype(int)]
        ds = ds.assign_coords({dim: decoded_labels})
print(ds)
# Out:
# landcover  >>>  {0: 'dynamic', 1: 'static'}
# model  >>>  {0: 'ACCESS1-0', 1: 'BCC-CSM1-1', 2: 'BNU-ESM', 3: 'CCSM4', 4: 'GFDL-ESM2G', 5: 'GFDL-ESM2M', 6: 'IPSL-CM5A-LR', 7: 'IPSL-CM5A-MR', 8: 'Maurer', 9: 'MIROC5', 10: 'MIROC-ESM', 11: 'MIROC-ESM-CHEM', 12: 'MRI-CGCM3', 13: 'NorESM1-M'}
# scenario  >>>  {0: 'historical', 1: 'rcp26', 2: 'rcp45', 3: 'rcp60', 4: 'rcp85'}
# era  >>>  {0: '1976-2005', 1: '2016-2045', 2: '2046-2075', 3: '2071-2100'}
# <xarray.Dataset> Size: 3GB
# Dimensions:    (landcover: 2, model: 14, scenario: 5, era: 4, stream_id: 56460)
# Coordinates:
#   * stream_id  (stream_id) int32 226kB 1 2 3 4 5 ... 56457 56458 56459 56460
#   * landcover  (landcover) <U7 56B 'dynamic' 'static'
#   * model      (model) <U14 784B 'ACCESS1-0' 'BCC-CSM1-1' ... 'NorESM1-M'
#   * scenario   (scenario) <U10 200B 'historical' 'rcp26' 'rcp45' 'rcp60' 'rcp85'
#   * era        (era) <U9 144B '1976-2005' '2016-2045' '2046-2075' '2071-2100'
# Data variables: (12/20)
# ...

# %% [markdown]
# ### Subset and compute ensemble
#
# Compute two model ensembles: (1) a projected ensemble for static landcover + RCP 6.0 + mid-century era, and (2) a historical GCM ensemble for static landcover + historical scenario + 1976-2005 era. The ensemble delta (projected GCM mean minus historical GCM mean) represents the climate change signal within the model space, free of GCM systematic bias. This delta is applied to the Maurer observational baseline to produce bias-corrected projected statistics. Use min, mean, and max operators for the projected ensemble; use mean only for the historical GCM ensemble. Also extract the Maurer historical observational data to a separate dataset. Round all values to 2 decimal places.

# %%
ds_proj_min = (
    ds.sel(landcover="static", scenario="rcp60", era="2046-2075")
    .min(dim="model")
    .assign_coords(model=["Ensemble"])
    .round(2)
)
ds_proj_mean = (
    ds.sel(landcover="static", scenario="rcp60", era="2046-2075")
    .mean(dim="model")
    .assign_coords(model=["Ensemble"])
    .round(2)
)
ds_proj_max = (
    ds.sel(landcover="static", scenario="rcp60", era="2046-2075")
    .max(dim="model")
    .assign_coords(model=["Ensemble"])
    .round(2)
)

# %%
ds_hist = ds.sel(
    landcover="static", model="Maurer", scenario="historical", era="1976-2005"
).round(2)

# GCM historical ensemble mean: average across all 13 GCMs for historical scenario, 1976-2005.
# Maurer is excluded because it is an observational product, not a GCM.
# skipna=True ensures that models missing a historical run do not corrupt the ensemble mean.
ds_hist_gcm_mean = (
    ds.sel(landcover="static", scenario="historical", era="1976-2005")
    .drop_sel(model="Maurer")
    .mean(dim="model", skipna=True)
    .round(2)
)

# %% [markdown]
# We need to add a variable `ma99` to the datasets: this represents our annual mean flow, which is calculated as the mean of all monthly mean flows.

# %%
monthly_flow_vars = [var for var in vars.keys() if var.startswith("ma")]

# historical (Maurer observational baseline)
ds_hist["ma99"] = ds_hist[monthly_flow_vars].to_array(dim="var").mean("var").round(2)

# GCM historical ensemble mean for ma99
ds_hist_gcm_mean["ma99"] = (
    ds_hist_gcm_mean[monthly_flow_vars].to_array(dim="var").mean("var").round(2)
)

# mean of projected means
ds_proj_mean["ma99"] = (
    ds_proj_mean[monthly_flow_vars].to_array(dim="var").mean("var").round(2)
)

# more complicated: we need the annual mean for each model, then take the minimum of those means
#  (ie, the model with the lowest annual mean)
# Compute annual mean for each model, then take the minimum of those means
annual_means = ds.sel(landcover="static", scenario="rcp60", era="2046-2075")[monthly_flow_vars].to_array(dim="var").mean("var")
min_annual_mean = annual_means.min(dim="model").round(2)
ds_proj_min["ma99"] = min_annual_mean

# same with max:
max_annual_mean = annual_means.max(dim="model").round(2)
ds_proj_max["ma99"] = max_annual_mean


# populate the lookup dict
vars["ma99"] = {"var_description": "Mean annual flow",
                "stats":["ma99_min_d", "ma99_avg_d", "ma99_max_d"], 
                "aggregation": ["minimum", "mean", "maximum"], 
                "stat_descriptions": [
                    "difference between minimum of ensemble ma99 values and GCM historical ensemble mean",
                    "difference between mean of ensemble ma99 values and GCM historical ensemble mean",
                    "difference between maximum of ensemble ma99 values and GCM historical ensemble mean"
                ],
                "units": "cfs", "difference": "percentage"}

# %% [markdown]
# ### Sanity checks
#
# If we subset the projected datasets by stream ID and variable, we get a single values representing min, mean, max of the ensemble. If we subset the historical dataset by stream ID and variable, we get a single value representing the historical baseline.

# %%
print(ds_proj_min["ma20"].sel(stream_id=56458).values)
print(ds_proj_mean["ma20"].sel(stream_id=56458).values)
print(ds_proj_max["ma20"].sel(stream_id=56458).values)
print("\n")
print(ds_hist["ma20"].sel(stream_id=56458).values)
# Out:
# 109.74
# 184.77
# 585.29
#
#
# 293.43

# %% [markdown]
# Check out some monthly flow values for a stream and confirm that the mean annual flow calculation worked.

# %%
for ds, label in zip([ds_proj_mean, ds_hist], ["Projected Mean", "Historical"]):

    print(
        f"{label} Monthly source values:",
        ds[monthly_flow_vars].sel(stream_id=56458).to_array().values,"\n"
    )
    
    print(
        f"{label} Mean of monthly source values:",
        ds[monthly_flow_vars].sel(stream_id=56458).to_array().values.mean().round(2),
    )
    
    print(
        f"{label} Dataset ma99 value:", ds["ma99"].sel(stream_id=56458).values.round(2)
    )
    print("\n")
# Out:
# Projected Mean Monthly source values: [1642.62 2625.91 2564.18 1920.17 1326.88  628.2   280.33  193.7   184.77
#   229.1   307.97  773.9 ]
#
# Projected Mean Mean of monthly source values: 1056.48
# Projected Mean Dataset ma99 value: 1056.48
#
#
# Historical Monthly source values: [ 680.56 1089.2  2089.3  2782.9  3957.7  3002.2  1331.2   560.28  293.43
#   219.02  366.09  482.07]
#
# Historical Mean of monthly source values: 1404.5
# Historical Dataset ma99 value: 1404.5

# %% [markdown]
# ### Calculate diffs
#
# For each variable, use the dictionary to determine the operator and compute differences in the specified units. Store the resulting data arrays in a list for tabulation later. Print a message showing values for a test stream ID. For the `ma99`, `dh15`, `dl16`, `fh1`, and `fl1` variables, also pass the Maurer historical values to the arrays list as `{var}_hist`.
#
# The ensemble delta is computed as: `projected_ensemble_{agg} - GCM_historical_ensemble_mean`. This isolates the climate change signal within the model space and removes GCM systematic bias. The delta is then applied to the Maurer observational baseline.
#
# For percentage variables the absolute ensemble delta is expressed as a fraction of the Maurer historical value (`delta / maurer_hist * 100`). This keeps Maurer as the single reference point throughout: a frontend can reconstruct the adjusted projected value as `maurer_hist * (1 + pct/100) = maurer_hist + absolute_delta`.
#
# NOTE: For variables using "day of year" units, we need to account for the year boundary when computing deltas. For this we use [modulo operator](https://www.datacamp.com/tutorial/modulo-operator-python). We shift the cycle by half a year during the initial difference calculation, and then back again after applying the module. This ensures the output represents the shortest path around the cycle. Read more in `modulo.md`.

# %%
diff_arrays = {}


for var in vars.keys():

    for stat, agg in zip(vars[var]["stats"], vars[var]["aggregation"]):

        stream_id = 56458

        print("\nOriginal Variable: ", var)
        print("Stat: ", stat)
        print(f"Test stream ID: {stream_id} ")

        unit = vars[var]["units"]
        diff = vars[var]["difference"]

        if agg == "minimum":
            if unit == "day of year":
                # Ensemble delta: projected GCM min minus GCM historical ensemble mean.
                # Modulo handles wrap-around at year boundary (see modulo.md).
                diff_ds = ((ds_proj_min[var] - ds_hist_gcm_mean[var] + (366 / 2)) % 366) - (
                    366 / 2
                )
            else:
                # Ensemble delta: projected GCM min minus GCM historical ensemble mean.
                diff_ds = ds_proj_min[var] - ds_hist_gcm_mean[var]

            print("     Historical (Maurer): ", ds_hist[var].sel(stream_id=stream_id).values, unit)
            print(
                "     Projected Min: ",
                ds_proj_min[var].sel(stream_id=stream_id).values,
                unit,
            )

        if agg == "mean":
            if unit == "day of year":
                # Ensemble delta: projected GCM mean minus GCM historical ensemble mean.
                # Modulo handles wrap-around at year boundary (see modulo.md).
                diff_ds = ((ds_proj_mean[var] - ds_hist_gcm_mean[var] + (366 / 2)) % 366) - (
                    366 / 2
                )
            else:
                # Ensemble delta: projected GCM mean minus GCM historical ensemble mean.
                diff_ds = ds_proj_mean[var] - ds_hist_gcm_mean[var]

            print("     Historical (Maurer): ", ds_hist[var].sel(stream_id=stream_id).values, unit)
            print(
                "     Projected Mean: ",
                ds_proj_mean[var].sel(stream_id=stream_id).values,
                unit,
            )

        if agg == "maximum":
            if unit == "day of year":
                # Ensemble delta: projected GCM max minus GCM historical ensemble mean.
                # Modulo handles wrap-around at year boundary (see modulo.md).
                diff_ds = ((ds_proj_max[var] - ds_hist_gcm_mean[var] + (366 / 2)) % 366) - (
                    366 / 2
                )
            else:
                # Ensemble delta: projected GCM max minus GCM historical ensemble mean.
                diff_ds = ds_proj_max[var] - ds_hist_gcm_mean[var]

            print("     Historical (Maurer): ", ds_hist[var].sel(stream_id=stream_id).values, unit)
            print(
                "     Projected Max: ",
                ds_proj_max[var].sel(stream_id=stream_id).values,
                unit,
            )
        if diff == "percentage":
            # express the ensemble delta as a fraction of the Maurer
            # historical baseline (ds_hist[var]), NOT the GCM historical ensemble mean.
            # diff_ds = projected_GCM_agg - GCM_historical_ensemble_mean  (the change signal)
            # denominator = ds_hist[var]  (Maurer) 
            # This keeps Maurer as the single reference: the frontend reconstructs the adjusted
            # projected value as maurer_hist * (1 + pct/100) = maurer_hist + absolute_delta.
            # Avoid division by zero - set to 0.0001 where Maurer historical value is 0.
            perc_diff_ds = xr.where(
                ds_hist[var] != 0,
                (diff_ds / ds_hist[var]) * 100.0,
                0.0001
            ).round(2)
            diff_arrays[stat] = perc_diff_ds
            # if perc_diff_ds is positive, add a + sign in message
            if perc_diff_ds.sel(stream_id=stream_id).values >= 0:
                print(
                    "     Difference (percentage): +",
                    perc_diff_ds.sel(stream_id=stream_id).values,
                    " %",
                    sep="",
                )
            else:
                print(
                    "     Difference (percentage): ",
                    perc_diff_ds.sel(stream_id=stream_id).values,
                    "%",
                )
        elif diff == "absolute":
            diff_arrays[stat] = diff_ds.round(2)
            # if diff_ds is positive, add a + sign in message
            if diff_ds.sel(stream_id=stream_id).values >= 0:
                print(
                    "     Difference (absolute): +",
                    diff_ds.sel(stream_id=stream_id).values,
                    " ",
                    unit,
                    sep="",
                )
            else:
                print(
                    "     Difference (absolute): ",
                    diff_ds.sel(stream_id=stream_id).values,
                    unit,
                )


diff_arrays["ma99_hist"] = ds_hist["ma99"]
diff_arrays["dh15_hist"] = ds_hist["dh15"]
diff_arrays["dl16_hist"] = ds_hist["dl16"]
diff_arrays["fh1_hist"] = ds_hist["fh1"]
diff_arrays["fl1_hist"] = ds_hist["fl1"]
# Out:
# Original Variable:  ma12
# Stat:  ma12_min_d
# Test stream ID: 56458
#      Historical (Maurer):  680.56 cfs
#      Projected Min:  845.94 cfs
#      Difference (percentage):  -43.09 %
#
# Original Variable:  ma12
# Stat:  ma12_avg_d
# Test stream ID: 56458
#      Historical (Maurer):  680.56 cfs
#      Projected Mean:  1642.62 cfs
#      Difference (percentage): +73.97 %
#
# Original Variable:  ma12
# Stat:  ma12_max_d
# Test stream ID: 56458
#      Historical (Maurer):  680.56 cfs
#      Projected Max:  2208.1 cfs
#      Difference (percentage): +157.06 %
#
# Original Variable:  ma13
# Stat:  ma13_min_d
# Test stream ID: 56458
#      Historical (Maurer):  1089.2 cfs
#      Projected Min:  1586.3 cfs
#      Difference (percentage):  -21.15 %
#
# Original Variable:  ma13
# Stat:  ma13_avg_d
# Test stream ID: 56458
#      Historical (Maurer):  1089.2 cfs
#      Projected Mean:  2625.91 cfs
#      Difference (percentage): +74.29 %
#
# Original Variable:  ma13
# Stat:  ma13_max_d
# ...

# %% [markdown]
# ### Convert Arrays to Dataframe
#
# Create a dataframe with stream IDs as index, and use the arrays to populate the rest of the columns.

# %%
df = pd.DataFrame(diff_arrays, index=diff_arrays["ma20_avg_d"].stream_id.values)
df
# Out:
#        ma12_min_d  ma12_avg_d  ma12_max_d  ma13_min_d  ma13_avg_d  ma13_max_d  \
# 1       30.680000   99.400002  203.190002   31.809999  122.279999  308.459991
# 2       43.259998   80.040001  131.720001   42.130001  106.820000  193.320007
# 3       26.990000   81.430000  138.949997   35.610001  102.379997  220.380005
# 4       27.209999   80.110001  134.460007   36.180000   99.470001  211.720001
# 5       42.500000   79.930000  132.259995   42.220001  106.260002  192.919998
# ...           ...         ...         ...         ...         ...         ...
# 56456         NaN         NaN         NaN         NaN         NaN         NaN
# 56457  -40.060001   -1.790000   64.050003  -42.060001   -8.490000   51.919998
# 56458  -43.090000   73.970001  157.059998  -21.150000   74.290001  186.270004
# 56459  -19.990000   10.660000   37.860001  -22.450001   -3.380000   19.120001
# 56460  -16.620001    5.600000   43.209999 -116.059998  -10.090000  127.519997
#
# ...

# %% [markdown]
# ### QC
#
# Pick 10 random stream IDs from the original dataset, reprocess, and test results against the dataframe.

# %%
# Pick 10 random stream IDs from the original dataset, and test results against the dataframe.
# We will just use the June monthly mean flow to test.

for _ in range(10):
    stream_id = random.choice(ds.stream_id.values.tolist())
    print(f"Testing stream ID: {stream_id} ")

    var = "ma20"
    print("     Historical value (Maurer):", ds_hist[var].sel(stream_id=stream_id).values)
    print(
        "     Projected Mean value:", ds_proj_mean[var].sel(stream_id=stream_id).values
    )
    print(
        "     GCM Historical Ensemble Mean:", ds_hist_gcm_mean[var].sel(stream_id=stream_id).values
    )
    print("     Calculated difference (percentage):", df.loc[stream_id, var + "_avg_d"])
    # Avoid division by zero in verification
    hist_val = ds_hist[var].sel(stream_id=stream_id)
    if hist_val.values != 0:
        # Ensemble delta: projected GCM mean minus GCM historical ensemble mean
        ensemble_delta = ds_proj_mean[var].sel(stream_id=stream_id) - ds_hist_gcm_mean[var].sel(stream_id=stream_id)
        # Express as percentage of Maurer baseline (Option A)
        calc_diff = (ensemble_delta / hist_val) * 100.0
        print("     Verified difference (percentage):", calc_diff.values)
    else:
        print("     Verified difference (percentage): NaN (Maurer historical value is 0)")
# Out:
# Testing stream ID: 42135
#      Historical value (Maurer): 0.78
#      Projected Mean value: 0.27
#      GCM Historical Ensemble Mean: 0.62
#      Calculated difference (percentage): -44.87
#      Verified difference (percentage): -44.87179517745972
# Testing stream ID: 45706
#      Historical value (Maurer): 0.02
#      Projected Mean value: 0.13
#      GCM Historical Ensemble Mean: 0.13
#      Calculated difference (percentage): 0.0
#      Verified difference (percentage): 0.0
# Testing stream ID: 21114
#      Historical value (Maurer): 27.7
#      Projected Mean value: 14.52
#      GCM Historical Ensemble Mean: 26.3
#      Calculated difference (percentage): -42.53
#      Verified difference (percentage): -42.52707064151764
# Testing stream ID: 13082
#      Historical value (Maurer): 6.89
#      Projected Mean value: 2.99
#      GCM Historical Ensemble Mean: 3.53
#      Calculated difference (percentage): -7.84
#      Verified difference (percentage): -7.837445288896561
# ...

# %% [markdown]
# ### Save to CSV
#
# Rename the index to "stream_id" so we can crosswalk this data into the shapefile, then save.

# %%
# Rename the index to "stream_id"
df.index.name = "stream_id"
df.to_csv("stats_diff.csv", index=True)

# %% [markdown]
# ### Save lookup dict to file
#
# Save the `vars` lookup dict to a standalone JSON for use in the app. Note that this lookup dict currently does not include the historical values (`ma99_hist`, `dh15_hist`, `dl16_hist`, `fh1_hist`, and `fl1_hist` variables). We can add these later if needed.

# %%
vars_json = json.dumps(vars, indent=4)
with open("shp_stats_lookup.json", "w") as f:
    f.write(vars_json)

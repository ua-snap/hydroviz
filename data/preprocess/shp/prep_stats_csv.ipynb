# %% [markdown]
# ## 4. Prep Statistics CSV
#
#
# Use this notebook to prepare hydrologic statistic attributes for addition to the segments shapefile. The stats are saved to a CSV. These stats are a subset of the full dataset designed for quick display on the webapp via WMS / WFS. Unless otherwise noted, we are providing the difference between static landcover, Maurer model, historical scenario, 1976-2005 era and static landcover, multi-model ensemble, RCP 6.0 scenario, 2046-2075 era.
#
#
# ### Which stats?
#
#
# #### Magnitude
#
#
# - `ma99_hist`: Mean Annual Flow (static landcover, Maurer model, historical scenario, 1976-2005 era)
#
#
#   - **note: this is for the default map view on the web app**
#
#
#   - statistic units = cfs
#
#
#   - difference units = NA
#
#
#
#
# - `ma99`: Mean Annual Flow
#
#
#   - `ma99_avg_d`: difference between mean of ensemble `ma99` values and Maurer historical
#
#
#   - `ma99_min_d`: difference between minimum of ensemble `ma99` values and Maurer historical
#
#
#   - `ma99_max_d`: difference between maximum of ensemble `ma99` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma12`: Mean January Flow
#
#
#   - `ma12_avg_d`: difference between mean of ensemble `ma12` values and Maurer historical
#
#
#   - `ma12_min_d`: difference between minimum of ensemble `ma12` values and Maurer historical
#
#
#   - `ma12_max_d`: difference between maximum of ensemble `ma12` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma13`: Mean February Flow
#
#
#   - `ma13_avg_d`: difference between mean of ensemble `ma13` values and Maurer historical
#
#
#   - `ma13_min_d`: difference between minimum of ensemble `ma13` values and Maurer historical
#
#
#   - `ma13_max_d`: difference between maximum of ensemble `ma13` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma14`: Mean March Flow
#
#
#   - `ma14_avg_d`: difference between mean of ensemble `ma14` values and Maurer historical
#
#
#   - `ma14_min_d`: difference between minimum of ensemble `ma14` values and Maurer historical
#
#
#   - `ma14_max_d`: difference between maximum of ensemble `ma14` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma15`: Mean April Flow
#
#
#   - `ma15_avg_d`: difference between mean of ensemble `ma15` values and Maurer historical
#
#
#   - `ma15_min_d`: difference between minimum of ensemble `ma15` values and Maurer historical
#
#
#   - `ma15_max_d`: difference between maximum of ensemble `ma15` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma16`: Mean May Flow
#
#
#   - `ma16_avg_d`: difference between mean of ensemble `ma16` values and Maurer historical
#
#
#   - `ma16_min_d`: difference between minimum of ensemble `ma16` values and Maurer historical
#
#
#   - `ma16_max_d`: difference between maximum of ensemble `ma16` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma17`: Mean June Flow
#
#
#   - `ma17_avg_d`: difference between mean of ensemble `ma17` values and Maurer historical
#
#
#   - `ma17_min_d`: difference between minimum of ensemble `ma17` values and Maurer historical
#
#
#   - `ma17_max_d`: difference between maximum of ensemble `ma17` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma18`: Mean July Flow
#
#
#   - `ma18_avg_d`: difference between mean of ensemble `ma18` values and Maurer historical
#
#
#   - `ma18_min_d`: difference between minimum of ensemble `ma18` values and Maurer historical
#
#
#   - `ma18_max_d`: difference between maximum of ensemble `ma18` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma19`: Mean August Flow
#
#
#   - `ma19_avg_d`: difference between mean of ensemble `ma19` values and Maurer historical
#
#
#   - `ma19_min_d`: difference between minimum of ensemble `ma19` values and Maurer historical
#
#
#   - `ma19_max_d`: difference between maximum of ensemble `ma19` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma20`: Mean September Flow
#
#
#   - `ma20_avg_d`: difference between mean of ensemble `ma20` values and Maurer historical
#
#
#   - `ma20_min_d`: difference between minimum of ensemble `ma20` values and Maurer historical
#
#
#   - `ma20_max_d`: difference between maximum of ensemble `ma20` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma21`: Mean October Flow
#
#
#   - `ma21_avg_d`: difference between mean of ensemble `ma21` values and Maurer historical
#
#
#   - `ma21_min_d`: difference between minimum of ensemble `ma21` values and Maurer historical
#
#
#   - `ma21_max_d`: difference between maximum of ensemble `ma21` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma22`: Mean November Flow
#
#
#   - `ma22_avg_d`: difference between mean of ensemble `ma22` values and Maurer historical
#
#
#   - `ma22_min_d`: difference between minimum of ensemble `ma22` values and Maurer historical
#
#
#   - `ma22_max_d`: difference between maximum of ensemble `ma22` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `ma23`: Mean December Flow
#
#
#   - `ma23_avg_d`: difference between mean of ensemble `ma23` values and Maurer historical
#
#
#   - `ma23_min_d`: difference between minimum of ensemble `ma23` values and Maurer historical
#
#
#   - `ma23_max_d`: difference between maximum of ensemble `ma23` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# #### Duration
#
#
# - `dh1`: Annual Maximum Daily Flow
#
#
#   - `dh1_max_d`: difference between maximum of ensemble `dh1` values and Maurer historical
#
#
#   - `dh1_min_d`: difference between minimum of ensemble `dh1` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `dl1`: Annual Minimum Daily Flow
#
#
#   - `dl1_max_d`: difference between maximum of ensemble `dl1` values and Maurer historical
#
#
#   - `dl1_min_d`: difference between minimum of ensemble `dl1` values and Maurer historical
#
#
#   - statistic units = cfs
#
#
#   - difference units = percentage +/-
#
#
#
#
# - `dh15`: High Flow Pulse Duration
#
#
#   - `dh15_max_d`: difference between maximum of ensemble `dh15` values and Maurer historical
#
#
#   - `dh15_min_d`: difference between minimum of ensemble `dh15` values and Maurer historical
#
#
#   - statistic units = days per year
#
#
#   - difference units = absolute +/-
#
#
#
#
# - `dl16`: Low Flow Pulse Duration
#
#
#   - `dl16_max_d`: difference between maximum of ensemble `dl16` values and Maurer historical
#
#
#   - `dl16_min_d`: difference between minimum of ensemble `dl16` values and Maurer historical
#
#
#   - statistic units = days per year
#
#
#   - difference units = absolute +/-
#
#
#
#
# #### Frequency
#
#
# - `fh1`: High Flood Pulse Count
#
#
#   - `fh1_max_d`: difference between maximum of ensemble `fh1` values and Maurer historical
#
#
#   - `fh1_min_d`: difference between minimum of ensemble `fh1` values and Maurer historical
#
#
#   - statistic units = events per year
#
#
#   - difference units = absolute +/-
#
#
#
#
# - `fl1`: Low Flood Pulse Count
#
#
#   - `fl1_max_d`: difference between maximum of ensemble `fl1` values and Maurer historical
#
#
#   - `fl1_min_d`: difference between minimum of ensemble `fl1` values and Maurer historical
#
#
#   - statistic units = events per year
#
#
#   - difference units = absolute +/-
#
#
#
#
# #### Timing
#
#
# - `th1`: Julian Date of Annual Maximum
#
#
#   - `th1_avg_d`: difference between mean of ensemble `th1` values and Maurer historical
#
#
#   - `th1_min_d`: difference between minimum of ensemble `th1` values and Maurer historical
#
#
#   - `th1_max_d`: difference between maximum of ensemble `th1` values and Maurer historical
#
#
#   - statistic units = day of year
#
#
#   - difference units = absolute +/-
#
#
#
#
# - `tl1`: Julian Date of Annual Minimum
#
#
#   - `tl1_avg_d`: difference between mean of ensemble `tl1` values and Maurer historical
#
#
#   - `tl1_min_d`: difference between minimum of ensemble `tl1` values and Maurer historical
#
#
#   - `tl1_max_d`: difference between maximum of ensemble `tl1` values and Maurer historical
#
#
#   - statistic units = day of year
#
#
#   - difference units = absolute +/-

# %% [markdown]
# ### Setup

# %%
import xarray as xr
import ast
import pandas as pd
import random
import json

# %%
vars = {
    "ma12": {
        "var_description": "Mean January flow",
        "stats": ["ma12_min_d", "ma12_avg_d", "ma12_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma12 values and Maurer historical",
            "difference between mean of ensemble ma12 values and Maurer historical",
            "difference between maximum of ensemble ma12 values and Maurer historical"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma13": {
        "var_description": "Mean February flow",
        "stats": ["ma13_min_d", "ma13_avg_d", "ma13_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma13 values and Maurer historical",
            "difference between mean of ensemble ma13 values and Maurer historical",
            "difference between maximum of ensemble ma13 values and Maurer historical"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma14": {
        "var_description": "Mean March flow",
        "stats": ["ma14_min_d", "ma14_avg_d", "ma14_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma14 values and Maurer historical",
            "difference between mean of ensemble ma14 values and Maurer historical",
            "difference between maximum of ensemble ma14 values and Maurer historical"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma15": {
        "var_description": "Mean April flow",
        "stats": ["ma15_min_d", "ma15_avg_d", "ma15_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma15 values and Maurer historical",
            "difference between mean of ensemble ma15 values and Maurer historical",
            "difference between maximum of ensemble ma15 values and Maurer historical"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma16": {
        "var_description": "Mean May flow",
        "stats": ["ma16_min_d", "ma16_avg_d", "ma16_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma16 values and Maurer historical",
            "difference between mean of ensemble ma16 values and Maurer historical",
            "difference between maximum of ensemble ma16 values and Maurer historical"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma17": {
        "var_description": "Mean June flow",
        "stats": ["ma17_min_d", "ma17_avg_d", "ma17_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma17 values and Maurer historical",
            "difference between mean of ensemble ma17 values and Maurer historical",
            "difference between maximum of ensemble ma17 values and Maurer historical"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma18": {
        "var_description": "Mean July flow",
        "stats": ["ma18_min_d", "ma18_avg_d", "ma18_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma18 values and Maurer historical",
            "difference between mean of ensemble ma18 values and Maurer historical",
            "difference between maximum of ensemble ma18 values and Maurer historical"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma19": {
        "var_description": "Mean August flow",
        "stats": ["ma19_min_d", "ma19_avg_d", "ma19_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma19 values and Maurer historical",
            "difference between mean of ensemble ma19 values and Maurer historical",
            "difference between maximum of ensemble ma19 values and Maurer historical"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma20": {
        "var_description": "Mean September flow",
        "stats": ["ma20_min_d", "ma20_avg_d", "ma20_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma20 values and Maurer historical",
            "difference between mean of ensemble ma20 values and Maurer historical",
            "difference between maximum of ensemble ma20 values and Maurer historical"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma21": {
        "var_description": "Mean October flow",
        "stats": ["ma21_min_d", "ma21_avg_d", "ma21_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma21 values and Maurer historical",
            "difference between mean of ensemble ma21 values and Maurer historical",
            "difference between maximum of ensemble ma21 values and Maurer historical"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma22": {
        "var_description": "Mean November flow",
        "stats": ["ma22_min_d", "ma22_avg_d", "ma22_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma22 values and Maurer historical",
            "difference between mean of ensemble ma22 values and Maurer historical",
            "difference between maximum of ensemble ma22 values and Maurer historical"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "ma23": {
        "var_description": "Mean December flow",
        "stats": ["ma23_min_d", "ma23_avg_d", "ma23_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble ma23 values and Maurer historical",
            "difference between mean of ensemble ma23 values and Maurer historical",
            "difference between maximum of ensemble ma23 values and Maurer historical"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "dh1": {
        "var_description": "Annual Maximum Daily Flow",
        "stats": ["dh1_min_d", "dh1_max_d"],
        "aggregation": ["minimum", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble dh1 values and Maurer historical",
            "difference between maximum of ensemble dh1 values and Maurer historical"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "dl1": {
        "var_description": "Annual Minimum Daily Flow",
        "stats": ["dl1_min_d", "dl1_max_d"],
        "aggregation": ["minimum", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble dl1 values and Maurer historical",
            "difference between maximum of ensemble dl1 values and Maurer historical"
        ],
        "units": "cfs",
        "difference": "percentage"
    },
    "dh15": {
        "var_description": "High Flow Pulse Duration",
        "stats": ["dh15_min_d", "dh15_max_d"],
        "aggregation": ["minimum", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble dh15 values and Maurer historical",
            "difference between maximum of ensemble dh15 values and Maurer historical"
        ],
        "units": "days per year",
        "difference": "absolute"
    },
    "dl16": {
        "var_description": "Low Flow Pulse Duration",
        "stats": ["dl16_min_d", "dl16_max_d"],
        "aggregation": ["minimum", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble dl16 values and Maurer historical",
            "difference between maximum of ensemble dl16 values and Maurer historical"
        ],
        "units": "days per year",
        "difference": "absolute"
    },
    "fh1": {
        "var_description": "High Flood Pulse Count",
        "stats": ["fh1_min_d", "fh1_max_d"],
        "aggregation": ["minimum", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble fh1 values and Maurer historical",
            "difference between maximum of ensemble fh1 values and Maurer historical"
        ],
        "units": "events per year",
        "difference": "absolute"
    },
    "fl1": {
        "var_description": "Low Flood Pulse Count",
        "stats": ["fl1_min_d", "fl1_max_d"],
        "aggregation": ["minimum", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble fl1 values and Maurer historical",
            "difference between maximum of ensemble fl1 values and Maurer historical"
        ],
        "units": "events per year",
        "difference": "absolute"
    },
    "th1": {
        "var_description": "Julian Date of Annual Maximum",
        "stats": ["th1_min_d", "th1_avg_d", "th1_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble th1 values and Maurer historical",
            "difference between mean of ensemble th1 values and Maurer historical",
            "difference between maximum of ensemble th1 values and Maurer historical"
        ],
        "units": "day of year",
        "difference": "absolute"
    },
    "tl1": {
        "var_description": "Julian Date of Annual Minimum",
        "stats": ["tl1_min_d", "tl1_avg_d", "tl1_max_d"],
        "aggregation": ["minimum", "mean", "maximum"],
        "stat_descriptions": [
            "difference between minimum of ensemble tl1 values and Maurer historical",
            "difference between mean of ensemble tl1 values and Maurer historical",
            "difference between maximum of ensemble tl1 values and Maurer historical"
        ],
        "units": "day of year",
        "difference": "absolute"
    }
    # ma99 handled separately
}

# %% [markdown]
# Load combined stats file and subset variables.

# %%
ds = xr.open_dataset(
    "/import/beegfs/CMIP6/jdpaul3/hydroviz_data/maurer/nc_stats_fix/seg.nc"
)
ds = ds[list(vars.keys())]

# %% [markdown]
# Decode the dataset dimensions using the encoding attributes.

# %%
for dim in ds.dims:
    if ds[dim].attrs.get("encoding"):
        print(dim, " >>> ", ds[dim].attrs["encoding"])
        encoding_dict = ast.literal_eval(ds[dim].attrs["encoding"])
        decoded_labels = [encoding_dict[k] for k in ds[dim].values.astype(int)]
        ds = ds.assign_coords({dim: decoded_labels})
print(ds)
# Out:
# landcover  >>>  {0: 'dynamic', 1: 'static'}
# model  >>>  {0: 'ACCESS1-0', 1: 'BCC-CSM1-1', 2: 'BNU-ESM', 3: 'CCSM4', 4: 'GFDL-ESM2G', 5: 'GFDL-ESM2M', 6: 'IPSL-CM5A-LR', 7: 'IPSL-CM5A-MR', 8: 'Maurer', 9: 'MIROC5', 10: 'MIROC-ESM', 11: 'MIROC-ESM-CHEM', 12: 'MRI-CGCM3', 13: 'NorESM1-M'}
# scenario  >>>  {0: 'historical', 1: 'rcp26', 2: 'rcp45', 3: 'rcp60', 4: 'rcp85'}
# era  >>>  {0: '1976-2005', 1: '2016-2045', 2: '2046-2075', 3: '2071-2100'}
# <xarray.Dataset> Size: 3GB
# Dimensions:    (landcover: 2, model: 14, scenario: 5, era: 4, stream_id: 56460)
# Coordinates:
#   * stream_id  (stream_id) int32 226kB 1 2 3 4 5 ... 56457 56458 56459 56460
#   * landcover  (landcover) <U7 56B 'dynamic' 'static'
#   * model      (model) <U14 784B 'ACCESS1-0' 'BCC-CSM1-1' ... 'NorESM1-M'
#   * scenario   (scenario) <U10 200B 'historical' 'rcp26' 'rcp45' 'rcp60' 'rcp85'
#   * era        (era) <U9 144B '1976-2005' '2016-2045' '2046-2075' '2071-2100'
# Data variables: (12/20)
# ...

# %% [markdown]
# ### Subset and compute ensemble
#
# Compute a model ensemble for the static + RCP 8.5 + late century era and reference in a new dataset. Use min, mean, and max operators. Extract the Maurer historical data to a new dataset as well. Round all values to 2 decimal places.

# %%
ds_proj_min = (
    ds.sel(landcover="static", scenario="rcp60", era="2046-2075")
    .min(dim="model")
    .assign_coords(model=["Ensemble"])
    .round(2)
)
ds_proj_mean = (
    ds.sel(landcover="static", scenario="rcp60", era="2046-2075")
    .mean(dim="model")
    .assign_coords(model=["Ensemble"])
    .round(2)
)
ds_proj_max = (
    ds.sel(landcover="static", scenario="rcp60", era="2046-2075")
    .max(dim="model")
    .assign_coords(model=["Ensemble"])
    .round(2)
)

# %%
ds_hist = ds.sel(
    landcover="static", model="Maurer", scenario="historical", era="1976-2005"
).round(2)

# %% [markdown]
# We need to add a variable `ma99` to the datasets: this represents our annual mean flow, which is calculated as the mean of all monthly mean flows.

# %%
monthly_flow_vars = [var for var in vars.keys() if var.startswith("ma")]

# historical
ds_hist["ma99"] = ds_hist[monthly_flow_vars].to_array(dim="var").mean("var").round(2)


# mean of projected means
ds_proj_mean["ma99"] = (
    ds_proj_mean[monthly_flow_vars].to_array(dim="var").mean("var").round(2)
)

# more complicated: we need the annual mean for each model, then take the minimum of those means
#  (ie, the model with the lowest annual mean)
# Compute annual mean for each model, then take the minimum of those means
annual_means = ds.sel(landcover="static", scenario="rcp60", era="2046-2075")[monthly_flow_vars].to_array(dim="var").mean("var")
min_annual_mean = annual_means.min(dim="model").round(2)
ds_proj_min["ma99"] = min_annual_mean

# same with max:
max_annual_mean = annual_means.max(dim="model").round(2)
ds_proj_max["ma99"] = max_annual_mean

# populate the variable reference dict
vars["ma99"] = {"var_description": "Mean annual flow",
                "stats":["ma99_min_d", "ma99_avg_d", "ma99_max_d"], 
                "aggregation": ["minimum", "mean", "maximum"], 
                "stat_descriptions": [
                    "difference between minimum of ensemble ma99 values and Maurer historical",
                    "difference between mean of ensemble ma99 values and Maurer historical",
                    "difference between maximum of ensemble ma99 values and Maurer historical"
                ],
                "units": "cfs", "difference": "percentage"}

# %% [markdown]
# ### Sanity checks
#
# If we subset the projected datasets by stream ID and variable, we get a single values representing min, mean, max of the ensemble. If we subset the historical dataset by stream ID and variable, we get a single value representing the historical baseline.

# %%
print(ds_proj_min["ma20"].sel(stream_id=56458).values)
print(ds_proj_mean["ma20"].sel(stream_id=56458).values)
print(ds_proj_max["ma20"].sel(stream_id=56458).values)
print("\n")
print(ds_hist["ma20"].sel(stream_id=56458).values)
# Out:
# 109.74
# 184.77
# 585.29
#
#
# 293.43

# %% [markdown]
# Check out some monthly flow values for a stream and confirm that the mean annual flow calculation worked.

# %%
for ds, label in zip([ds_proj_mean, ds_hist], ["Projected Mean", "Historical"]):

    print(
        f"{label} Monthly source values:",
        ds[monthly_flow_vars].sel(stream_id=56458).to_array().values,"\n"
    )
    
    print(
        f"{label} Mean of monthly source values:",
        ds[monthly_flow_vars].sel(stream_id=56458).to_array().values.mean().round(2),
    )
    
    print(
        f"{label} Dataset ma99 value:", ds["ma99"].sel(stream_id=56458).values.round(2)
    )
    print("\n")
# Out:
# Projected Mean Monthly source values: [1642.62 2625.91 2564.18 1920.17 1326.88  628.2   280.33  193.7   184.77
#   229.1   307.97  773.9 ]
#
# Projected Mean Mean of monthly source values: 1056.48
# Projected Mean Dataset ma99 value: 1056.48
#
#
# Historical Monthly source values: [ 680.56 1089.2  2089.3  2782.9  3957.7  3002.2  1331.2   560.28  293.43
#   219.02  366.09  482.07]
#
# Historical Mean of monthly source values: 1404.5
# Historical Dataset ma99 value: 1404.5

# %% [markdown]
# ### Calculate diffs
#
# For each variable, use the dictionary to determine the operator and compute differences in the specified units. Store the resulting data arrays in a list for tabulation later. Print a message showing values for a test stream ID. For the `ma99` variable, also pass the historical values to the arrays list as variable `ma99_hist` for our default map view.
#
# NOTE: For variables using "day of year" units, we need to account for the year boundary when computing deltas. For this we use [modulo operator](https://www.datacamp.com/tutorial/modulo-operator-python). We shift the cycle by half a year during the initial difference calculation, and then back again after applying the module. This ensures the output represents the shortest path around the cycle. Read more in `modulo.md`.

# %%
diff_arrays = {}


for var in vars.keys():

    for stat, agg in zip(vars[var]["stats"], vars[var]["aggregation"]):

        stream_id = 56458

        print("\nOriginal Variable: ", var)
        print("Stat: ", stat)
        print(f"Test stream ID: {stream_id} ")

        unit = vars[var]["units"]
        diff = vars[var]["difference"]

        if agg == "minimum":
            if unit == "day of year":
                diff_ds = ((ds_proj_min[var] - ds_hist[var] + (366 / 2)) % 366) - (
                    366 / 2
                )  # account for wrap-around at year boundary
            else:
                diff_ds = ds_proj_min[var] - ds_hist[var]

            print("     Historical: ", ds_hist[var].sel(stream_id=stream_id).values, unit)
            print(
                "     Projected Min: ",
                ds_proj_min[var].sel(stream_id=stream_id).values,
                unit,
            )

        if agg == "mean":
            if unit == "day of year":
                diff_ds = ((ds_proj_mean[var] - ds_hist[var] + (366 / 2)) % 366) - (
                    366 / 2
                )  # account for wrap-around at year boundary
            else:
                diff_ds = ds_proj_mean[var] - ds_hist[var]

            print("     Historical: ", ds_hist[var].sel(stream_id=stream_id).values, unit)
            print(
                "     Projected Mean: ",
                ds_proj_mean[var].sel(stream_id=stream_id).values,
                unit,
            )

        if agg == "maximum":
            if unit == "day of year":
                diff_ds = ((ds_proj_max[var] - ds_hist[var] + (366 / 2)) % 366) - (
                    366 / 2
                )  # account for wrap-around at year boundary
            else:
                diff_ds = ds_proj_max[var] - ds_hist[var]

            print("     Historical: ", ds_hist[var].sel(stream_id=stream_id).values, unit)
            print(
                "     Projected Max: ",
                ds_proj_max[var].sel(stream_id=stream_id).values,
                unit,
            )
        if diff == "percentage":
            perc_diff_ds = ((diff_ds / ds_hist[var]) * 100.0).round(2)
            diff_arrays[stat] = perc_diff_ds
            # if perc_diff_ds is positive, add a + sign in message
            if perc_diff_ds.sel(stream_id=stream_id).values >= 0:
                print(
                    "     Difference (percentage): +",
                    perc_diff_ds.sel(stream_id=stream_id).values,
                    " %",
                    sep="",
                )
            else:
                print(
                    "     Difference (percentage): ",
                    perc_diff_ds.sel(stream_id=stream_id).values,
                    "%",
                )
        elif diff == "absolute":
            diff_arrays[stat] = diff_ds.round(2)
            # if diff_ds is positive, add a + sign in message
            if diff_ds.sel(stream_id=stream_id).values >= 0:
                print(
                    "     Difference (absolute): +",
                    diff_ds.sel(stream_id=stream_id).values,
                    " ",
                    unit,
                    sep="",
                )
            else:
                print(
                    "     Difference (absolute): ",
                    diff_ds.sel(stream_id=stream_id).values,
                    unit,
                )


diff_arrays["ma99_hist"] = ds_hist["ma99"]
# Out:
# Original Variable:  ma12
# Stat:  ma12_min_d
# Test stream ID: 56458
#      Historical:  680.56 cfs
#      Projected Min:  845.94 cfs
#      Difference (percentage): +24.3 %
#
# Original Variable:  ma12
# Stat:  ma12_avg_d
# Test stream ID: 56458
#      Historical:  680.56 cfs
#      Projected Mean:  1642.62 cfs
#      Difference (percentage): +141.36 %
#
# Original Variable:  ma12
# Stat:  ma12_max_d
# Test stream ID: 56458
#      Historical:  680.56 cfs
#      Projected Max:  2208.1 cfs
#      Difference (percentage): +224.45 %
#
# Original Variable:  ma13
# Stat:  ma13_min_d
# Test stream ID: 56458
#      Historical:  1089.2 cfs
#      Projected Min:  1586.3 cfs
#      Difference (percentage): +45.64 %
#
# Original Variable:  ma13
# Stat:  ma13_avg_d
# Test stream ID: 56458
#      Historical:  1089.2 cfs
#      Projected Mean:  2625.91 cfs
#      Difference (percentage): +141.09 %
#
# Original Variable:  ma13
# Stat:  ma13_max_d
# Test stream ID: 56458
# ...

# %% [markdown]
# ### Convert Arrays to Dataframe
#
# Create a dataframe with stream IDs as index, and use the arrays to populate the rest of the columns.

# %%
df = pd.DataFrame(diff_arrays, index=diff_arrays["ma20_avg_d"].stream_id.values)
df
# Out:
#        ma12_min_d  ma12_avg_d  ma12_max_d  ma13_min_d  ma13_avg_d  ma13_max_d  \
# 1        3.060000   71.790001  175.570007   -6.110000   84.360001  270.540009
# 2       67.620003  104.389999  156.070007   48.290001  112.980003  199.490005
# 3       14.640000   69.080002  126.589996   12.870000   79.629997  197.630005
# 4       17.510000   70.410004  124.750000   16.740000   80.029999  192.279999
# 5       64.769997  102.209999  154.539993   48.240002  112.279999  198.940002
# ...           ...         ...         ...         ...         ...         ...
# 56456         NaN         NaN         NaN         NaN         NaN         NaN
# 56457  -74.290001  -36.020000   29.820000  -79.720001  -46.150002   14.270000
# 56458   24.299999  141.360001  224.449997   45.639999  141.089996  253.070007
# 56459    0.220000   30.870001   58.070000   -4.590000   14.480000   36.980000
# 56460  -92.500000  -70.279999  -32.669998  -85.320000   20.639999  158.259995
#
# ...

# %% [markdown]
# ### QC
#
# Pick 10 random stream IDs from the original dataset, reprocess, and test results against the dataframe.

# %%
# Pick 10 random stream IDs from the original dataset, and test results against the dataframe.
# We will just use the June monthly mean flow to test.

for _ in range(10):
    stream_id = random.choice(ds.stream_id.values.tolist())
    print(f"Testing stream ID: {stream_id} ")

    var = "ma20"
    print("     Historical value:", ds_hist[var].sel(stream_id=stream_id).values)
    print(
        "     Projected Mean value:", ds_proj_mean[var].sel(stream_id=stream_id).values
    )
    print("     Calculated difference (percentage):", df.loc[stream_id, var + "_avg_d"])
    calc_diff = (
        (
            ds_proj_mean[var].sel(stream_id=stream_id)
            - ds_hist[var].sel(stream_id=stream_id)
        )
        / ds_hist[var].sel(stream_id=stream_id)
    ) * 100.0
    print("     Verified difference (percentage):", calc_diff.values)
# Out:
# Testing stream ID: 43063
#      Historical value: 33.56
#      Projected Mean value: 27.45
#      Calculated difference (percentage): -18.21
#      Verified difference (percentage): -18.206198513507843
# Testing stream ID: 14336
#      Historical value: 159.36
#      Projected Mean value: 68.19
#      Calculated difference (percentage): -57.21
#      Verified difference (percentage): -57.21008777618408
# Testing stream ID: 54396
#      Historical value: 0.13
#      Projected Mean value: 0.14
#      Calculated difference (percentage): 7.69
#      Verified difference (percentage): 7.692312449216843
# Testing stream ID: 40832
#      Historical value: 173.94
#      Projected Mean value: 245.0
#      Calculated difference (percentage): 40.85
#      Verified difference (percentage): 40.853166580200195
# Testing stream ID: 2051
#      Historical value: 850.42
#      Projected Mean value: 521.14
#      Calculated difference (percentage): -38.72
# ...

# %% [markdown]
# ### Save to CSV
#
# Rename the index to "stream_id" so we can crosswalk this data into the shapefile, then save.

# %%
# Rename the index to "stream_id"
df.index.name = "stream_id"
df.to_csv("stats_diff.csv", index=True)

# %% [markdown]
# ### Save lookup dict to file
#
# Save the `vars` lookup dict to a standalone JSON for use in the app.

# %%
vars_json = json.dumps(vars, indent=4)
with open("shp_stats_lookup.json", "w") as f:
    f.write(vars_json)

# %% [markdown]
# #### Download from ScienceBase
#
# This notebook downloads the SECASC hydrological futures dataset from ScienceBase using their API, which means direct download from AWS S3 buckets instead of point and click downloads from their web interface. This notebook follows usage instructions in their github [documentation](https://github.com/DOI-USGS/sciencebasepy/blob/master/README.md).
#
# Only use this notebook if you need your own copy of the dataset. Otherwise just use the data located in the directory below.

# %%
import sciencebasepy
import os
from pathlib import Path

dir = Path("/import/beegfs/CMIP6/jdpaul3/hydroviz_data")

# %% [markdown]
# Establish a session and get public items.  No need to log in!

# %%
sb = sciencebasepy.SbSession()

# This is the streamflow item from here: https://www.sciencebase.gov/catalog/item/638763a9d34ed907bf78432b
items = ['638763a9d34ed907bf78432b']
# Add the GIS item from here: https://www.sciencebase.gov/catalog/item/6373c4bdd34ed907bf6c6e4d
items += ['6373c4bdd34ed907bf6c6e4d']

# %% [markdown]
# Get item JSON and confirm these are the items we want by printing the titles.

# %%
items_json = [sb.get_item(item) for item in items]
for item_json in items_json: print(item_json['title'])
# Out:
# Streamflow Statistics for Hydrologic Simulations for the Conterminous United States for Historical and Future Conditions Using the National Hydrologic Model Infrastructure (NHM) and the Coupled Model Intercomparison Project Phase 5 (CMIP5), 1950 - 2100
# GIS Features Used With Hydrologic Simulations for the Conterminous United States for Historical and Future Conditions Using the National Hydrologic Model Infrastructure (NHM) and the Coupled Model Intercomparison Project Phase 5 (CMIP5), 1950 - 2100

# %% [markdown]
# Download all of the files associated with each item. This took me 5-10 minutes but may vary depending on the API and network.

# %%
subdirs = ["stats", "gis"]
for i, d in zip(items_json, subdirs):
    path = dir.joinpath(d)
    if not os.path.exists(path):
        os.makedirs(path)
    r = sb.get_item_files(i, path)
    print ("Downloaded files " + str(r))
# Out:
# downloading https://sciencebase.usgs.gov/manager/item/638763a9d34ed907bf78432b/file/clb5essaf00h80spj1vta1wld to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_BNU-ESM_r1i1p1_diff.zip
# downloading https://sciencebase.usgs.gov/manager/item/638763a9d34ed907bf78432b/file/cliungpv000190upncoucdzct to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_ACCESS1-0_r1i1p1.zip
# downloading https://sciencebase.usgs.gov/manager/item/638763a9d34ed907bf78432b/file/cliungrce001b0upn0pi4eikl to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_BNU-ESM_r1i1p1.zip
# downloading https://sciencebase.usgs.gov/manager/item/638763a9d34ed907bf78432b/file/clb55njeo00gz0spj87sv5q3c to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_Maurer.zip
# downloading https://sciencebase.usgs.gov/manager/item/638763a9d34ed907bf78432b/file/clb5eqcun00gi0mo017nr3qj3 to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_ACCESS1-0_r1i1p1_diff.zip
# downloading https://sciencebase.usgs.gov/manager/item/638763a9d34ed907bf78432b/file/clb5esrkf00h70spjbgejcwks to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_bcc-csm1-1_r1i1p1_diff.zip
# downloading https://sciencebase.usgs.gov/manager/item/638763a9d34ed907bf78432b/file/cliungqmj001a0upnc5i534po to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_bcc-csm1-1_r1i1p1.zip
# downloading https://sciencebase.usgs.gov/manager/item/638763a9d34ed907bf78432b/file/clb5est5200h90spj21tzha8a to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_CCSM4_r1i1p1_diff.zip
# downloading https://sciencebase.usgs.gov/manager/item/638763a9d34ed907bf78432b/file/clb3wneat00e00mo0aq9y8zqp to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_CCSM4_r1i1p1.zip
# downloading https://sciencebase.usgs.gov/manager/item/638763a9d34ed907bf78432b/file/clb5esu0t00ha0spjdpre5iry to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2G_r1i1p1_diff.zip
# downloading https://sciencebase.usgs.gov/manager/item/638763a9d34ed907bf78432b/file/clb3wzz0r00ev0spj3owagyj7 to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2G_r1i1p1.zip
# downloading https://sciencebase.usgs.gov/manager/item/638763a9d34ed907bf78432b/file/clb5esur400hb0spj4fg33dx0 to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2M_r1i1p1_diff.zip
# downloading https://sciencebase.usgs.gov/manager/item/638763a9d34ed907bf78432b/file/clb3x08id00ew0spjdxiraeel to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2M_r1i1p1.zip
# downloading https://www.sciencebase.gov/catalog/file/get/638763a9d34ed907bf78432b?f=__disk__19%2Feb%2F82%2F19eb8284a3108b68612d2e1c387225a12cc9675d to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_r1i1p1_diff.zip
# downloading https://www.sciencebase.gov/catalog/file/get/638763a9d34ed907bf78432b?f=__disk__d1%2F21%2Fd4%2Fd121d458a76b5317cfa783cc74006b338a42ae9c to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_r1i1p1.zip
# downloading https://www.sciencebase.gov/catalog/file/get/638763a9d34ed907bf78432b?f=__disk__fe%2F0a%2F6d%2Ffe0a6dd5ca0909087d4cd15ae8a6afa3304c816c to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_r1i1p1.zip
# downloading https://www.sciencebase.gov/catalog/file/get/638763a9d34ed907bf78432b?f=__disk__0c%2F44%2F0f%2F0c440f7040f78d0263228c0a2c11403aefb02fec to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_r1i1p1_diff.zip
# downloading https://www.sciencebase.gov/catalog/file/get/638763a9d34ed907bf78432b?f=__disk__67%2Ffa%2F10%2F67fa1083e68e2e12dde1965ef74148cf09b6b49d to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_r1i1p1.zip
# downloading https://www.sciencebase.gov/catalog/file/get/638763a9d34ed907bf78432b?f=__disk__2f%2Fd1%2F43%2F2fd14335a4e55c9b27c03e4b885518bf1d7f21b1 to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_r1i1p1_diff.zip
# downloading https://www.sciencebase.gov/catalog/file/get/638763a9d34ed907bf78432b?f=__disk__33%2Fd4%2Ff0%2F33d4f09c8562db846f910f0fc40b0f4c99bca49d to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_r1i1p1.zip
# downloading https://www.sciencebase.gov/catalog/file/get/638763a9d34ed907bf78432b?f=__disk
to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/nhm_segment_id_crosswalk.csv
# downloading https://www.sciencebase.gov/catalog/file/get/6373c4bdd34ed907bf6c6e4d?f=__disk__84%2Fe5%2Fdc%2F84e5dca79f8e95fe5ad00604dee78194527ad455 to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/Segments_subset.zip
# downloading https://sciencebase.usgs.gov/manager/item/6373c4bdd34ed907bf6c6e4d/file/cld9dvtsz000g0smn6e15cz9h to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/HRU_subset.zip
# downloading https://www.sciencebase.gov/catalog/file/get/6373c4bdd34ed907bf6c6e4d?f=__disk__37%2Fd5%2F09%2F37d5093af5db3b3dc29defe2a5c5b6547780c453 to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/hydrologic_regions_map_USGS.png
# downloading https://www.sciencebase.gov/catalog/file/get/6373c4bdd34ed907bf6c6e4d?f=__disk__65%2Ff1%2F76%2F65f176f79dcf562985d4343d5c056fa423c6c815 to /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/GIS_features_used_in_simulations_metadata.xml
# Downloaded files [{'url': 'https://www.sciencebase.gov/catalog/file/get/6373c4bdd34ed907bf6c6e4d?f=__disk__f6%2F79%2F2c%2Ff6792ce941b1f8090a3f3af3cfe438018a0e32d2', 'name': 'nhm_hru_id_crosswalk.csv', 'size': 1427078, 'originalMetadata': False, 'contentType': 'text/csv'}, {'url': 'https://www.sciencebase.gov/catalog/file/get/6373c4bdd34ed907bf6c6e4d?f=__disk__ec%2F69%2Fe7%2Fec69e7e9bf3ab40f2d893910c5c63ca1fa2a29f0', 'name': 'nhm_segment_id_crosswalk.csv', 'size': 711787, 'originalMetadata': False, 'contentType': 'text/csv'}, {'url': 'https://www.sciencebase.gov/catalog/file/get/6373c4bdd34ed907bf6c6e4d?f=__disk__84%2Fe5%2Fdc%2F84e5dca79f8e95fe5ad00604dee78194527ad455', 'name': 'Segments_subset.zip', 'size': 124281571, 'originalMetadata': False, 'contentType': 'application/zip'}, {'url': 'https://sciencebase.usgs.gov/manager/item/6373c4bdd34ed907bf6c6e4d/file/cld9dvtsz000g0smn6e15cz9h', 'name': 'HRU_subset.zip', 'size': 1722565731, 'originalMetadata': False, 'contentType': 'application/zip'}, {'url': 'https://www.sciencebase.gov/catalog/file/get/6373c4bdd34ed907bf6c6e4d?f=__disk__37%2Fd5%2F09%2F37d5093af5db3b3dc29defe2a5c5b6547780c453', 'name': 'hydrologic_regions_map_USGS.png', 'size': 54392, 'originalMetadata': False, 'contentType': 'image/png'}, {'url': 'https://www.sciencebase.gov/catalog/file/get/6373c4bdd34ed907bf6c6e4d?f=__disk__65%2Ff1%2F76%2F65f176f79dcf562985d4343d5c056fa423c6c815', 'name': 'GIS_features_used_in_simulations_metadata.xml', 'size': 29534, 'originalMetadata': True, 'contentType': 'application/fgdc+xml'}]

# %% [markdown]
# Some of these had unzipping problems in preliminary testing, so maybe we should check md5 sums before proceeding. Let's get md5 values for each file, and also indicate whether md5 values are missing.

# %%
md5_ok = []
md5_missing = []

for i in items_json:
    for file in i['files']:
        if file['checksum'] != None:
            #print(file['name'], ": MD5 = ", file['checksum']['value'])
            md5_ok.append(file['name'])
        if file['checksum'] == None:
            #print(file['name'], ": MD5 = missing!")
            md5_missing.append(file['name'])

print("Files with MD5 checksum metadata: ", len(md5_ok))
print("Files missing MD5 checksum metadata: ", len(md5_missing))
# Out:
# Files with MD5 checksum metadata:  48
# Files missing MD5 checksum metadata:  14

# %% [markdown]
# With 14 missing md5 values, it appears we cannot check those md5 sums! But we can check the rest:

# %%
for file in items_json[0]['files']:
    if file['checksum'] != None:
        #print('Checking file: ', file['name'], '...')
        md5_metadata = file['checksum']['value']
        filepath = str(list(dir.glob(f'**/{file["name"]}'))[0])
        output_string = !md5sum {filepath}
        md5_computed = output_string[0].split()[0]
        assert md5_metadata == md5_computed, 'MD5 checksums do not match for file: ' + file['name']

# %% [markdown]
# OK those look good, so let's unzip them. The unzipper will fail on all the non zip files, and thats OK.

# %%
for file in md5_ok:
    filepath = str(list(dir.glob(f'**/{file}'))[0])
    output_subdir = list(dir.glob(f'**/{file}'))[0].parent
    print('Unzipping file: ', file, ' into ', output_subdir)
    # !unzip {filepath} -d {output_subdir}
# Out:
# Unzipping file:  dynamic_IPSL-CM5A-LR_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_r1i1p1_diff.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp26_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp26_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp26_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp26_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp26_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp26_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp45_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp45_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp45_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp45_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp45_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp45_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp60_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp60_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp60_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp60_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp60_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp60_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp85_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp85_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp85_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp85_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp85_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp85_r1i1p1_seg_2071_2100_1976_2005_diff.csv
# Unzipping file:  dynamic_IPSL-CM5A-LR_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_r1i1p1.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_historical_r1i1p1_hru_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_historical_r1i1p1_hru_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_historical_r1i1p1_seg_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_historical_r1i1p1_seg_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp26_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp26_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp26_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp26_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp26_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp26_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp45_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp45_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp45_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp45_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp45_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp45_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp60_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp60_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp60_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp60_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp60_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp60_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp85_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp85_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp85_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp85_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp85_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-LR_rcp85_r1i1p1_seg_2071_2100.csv
# Unzipping file:  dynamic_IPSL-CM5A-MR_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_r1i1p1.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_historical_r1i1p1_hru_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_historical_r1i1p1_hru_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_historical_r1i1p1_seg_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_historical_r1i1p1_seg_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp26_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp26_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp26_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp26_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp26_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp26_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp45_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp45_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp45_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp45_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp45_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp45_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp60_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp60_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp60_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp60_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp60_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp60_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp85_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp85_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp85_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp85_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp85_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp85_r1i1p1_seg_2071_2100.csv
# Unzipping file:  dynamic_IPSL-CM5A-MR_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_r1i1p1_diff.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp26_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp26_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp26_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp26_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp26_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp26_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp45_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp45_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp45_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp45_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp45_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp45_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp60_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp60_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp60_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp60_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp60_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp60_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp85_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp85_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp85_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp85_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp85_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_IPSL-CM5A-MR_rcp85_r1i1p1_seg_2071_2100_1976_2005_diff.csv
# Unzipping file:  dynamic_MIROC5_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_r1i1p1.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_historical_r1i1p1_hru_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_historical_r1i1p1_hru_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_historical_r1i1p1_seg_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_historical_r1i1p1_seg_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp26_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp26_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp26_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp26_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp26_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp26_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp45_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp45_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp45_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp45_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp45_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp45_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp60_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp60_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp60_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp60_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp60_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp60_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp85_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp85_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp85_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp85_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp85_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp85_r1i1p1_seg_2071_2100.csv
# Unzipping file:  dynamic_MIROC5_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_r1i1p1_diff.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp26_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp26_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp26_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp26_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp26_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp26_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp45_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp45_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp45_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp45_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp45_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp45_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp60_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp60_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp60_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp60_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp60_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp60_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp85_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp85_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp85_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp85_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp85_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC5_rcp85_r1i1p1_seg_2071_2100_1976_2005_diff.csv
# Unzipping file:  dynamic_MIROC-ESM_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_r1i1p1.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_historical_r1i1p1_hru_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_historical_r1i1p1_hru_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_historical_r1i1p1_seg_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_historical_r1i1p1_seg_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp26_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp26_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp26_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp26_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp26_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp26_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp45_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp45_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp45_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp45_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp45_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp45_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp60_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp60_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp60_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp60_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp60_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp60_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp85_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp85_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp85_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp85_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp85_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp85_r1i1p1_seg_2071_2100.csv
# Unzipping file:  dynamic_MIROC-ESM_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_r1i1p1_diff.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp26_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp26_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp26_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp26_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp26_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp26_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp45_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp45_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp45_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp45_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp45_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp45_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp60_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp60_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp60_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp60_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp60_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp60_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp85_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp85_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp85_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp85_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp85_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM_rcp85_r1i1p1_seg_2071_2100_1976_2005_diff.csv
# Unzipping file:  dynamic_MIROC-ESM-CHEM_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_r1i1p1.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_historical_r1i1p1_hru_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_historical_r1i1p1_hru_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_historical_r1i1p1_seg_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_historical_r1i1p1_seg_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp26_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp26_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp26_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp26_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp26_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp26_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp45_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp45_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp45_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp45_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp45_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp45_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp60_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp60_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp60_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp60_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp60_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp60_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp85_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp85_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp85_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp85_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp85_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp85_r1i1p1_seg_2071_2100.csv
# Unzipping file:  dynamic_MIROC-ESM-CHEM_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_r1i1p1_diff.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp26_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp26_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp26_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp26_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp26_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp26_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp45_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp45_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp45_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp45_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp45_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp45_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp60_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp60_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp60_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp60_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp60_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp60_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp85_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp85_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp85_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp85_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp85_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MIROC-ESM-CHEM_rcp85_r1i1p1_seg_2071_2100_1976_2005_diff.csv
# Unzipping file:  dynamic_MRI-CGCM3_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_r1i1p1.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_historical_r1i1p1_hru_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_historical_r1i1p1_hru_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_historical_r1i1p1_seg_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_historical_r1i1p1_seg_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp26_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp26_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp26_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp26_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp26_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp26_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp45_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp45_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp45_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp45_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp45_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp45_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp60_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp60_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp60_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp60_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp60_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp60_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp85_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp85_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp85_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp85_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp85_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp85_r1i1p1_seg_2071_2100.csv
# Unzipping file:  dynamic_MRI-CGCM3_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_r1i1p1_diff.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp26_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp26_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp26_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp26_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp26_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp26_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp45_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp45_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp45_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp45_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp45_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp45_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp60_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp60_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp60_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp60_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp60_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp60_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp85_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp85_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp85_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp85_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp85_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_MRI-CGCM3_rcp85_r1i1p1_seg_2071_2100_1976_2005_diff.csv
# Unzipping file:  dynamic_NorESM1-M_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_r1i1p1.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_historical_r1i1p1_hru_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_historical_r1i1p1_hru_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_historical_r1i1p1_seg_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_historical_r1i1p1_seg_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp26_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp26_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp26_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp26_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp26_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp26_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp45_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp45_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp45_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp45_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp45_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp45_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp60_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp60_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp60_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp60_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp60_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp60_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp85_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp85_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp85_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp85_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp85_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp85_r1i1p1_seg_2071_2100.csv
# Unzipping file:  dynamic_NorESM1-M_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_r1i1p1_diff.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp26_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp26_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp26_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp26_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp26_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp26_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp45_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp45_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp45_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp45_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp45_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp45_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp60_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp60_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp60_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp60_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp60_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp60_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp85_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp85_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp85_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp85_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp85_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_NorESM1-M_rcp85_r1i1p1_seg_2071_2100_1976_2005_diff.csv
# Unzipping file:  static_ACCESS1-0_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_ACCESS1-0_r1i1p1.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_ACCESS1-0_historical_r1i1p1_hru_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_ACCESS1-0_historical_r1i1p1_hru_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_ACCESS1-0_historical_r1i1p1_seg_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_ACCESS1-0_historical_r1i1p1_seg_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_ACCESS1-0_rcp45_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_ACCESS1-0_rcp45_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_ACCESS1-0_rcp45_r1i1p1_hru_2071_2100.csv
# ...
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp85_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp85_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp85_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp85_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp85_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp85_r1i1p1_seg_2071_2100.csv
# Unzipping file:  static_MRI-CGCM3_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_r1i1p1_diff.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp26_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp26_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp26_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp26_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp26_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp26_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp45_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp45_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp45_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp45_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp45_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp45_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp60_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp60_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp60_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp60_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp60_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp60_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp85_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp85_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp85_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp85_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp85_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_MRI-CGCM3_rcp85_r1i1p1_seg_2071_2100_1976_2005_diff.csv
# Unzipping file:  static_NorESM1-M_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_r1i1p1.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_historical_r1i1p1_hru_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_historical_r1i1p1_hru_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_historical_r1i1p1_seg_1952_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_historical_r1i1p1_seg_1976_2005.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp26_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp26_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp26_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp26_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp26_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp26_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp45_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp45_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp45_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp45_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp45_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp45_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp60_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp60_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp60_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp60_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp60_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp60_r1i1p1_seg_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp85_r1i1p1_hru_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp85_r1i1p1_hru_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp85_r1i1p1_hru_2071_2100.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp85_r1i1p1_seg_2016_2045.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp85_r1i1p1_seg_2046_2075.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp85_r1i1p1_seg_2071_2100.csv
# Unzipping file:  static_NorESM1-M_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_r1i1p1_diff.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp26_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp26_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp26_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp26_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp26_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp26_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp45_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp45_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp45_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp45_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp45_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp45_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp60_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp60_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp60_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp60_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp60_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp60_r1i1p1_seg_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp85_r1i1p1_hru_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp85_r1i1p1_hru_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp85_r1i1p1_hru_2071_2100_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp85_r1i1p1_seg_2016_2045_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp85_r1i1p1_seg_2046_2075_1976_2005_diff.csv
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/static_NorESM1-M_rcp85_r1i1p1_seg_2071_2100_1976_2005_diff.csv
# Unzipping file:  streamflow_statistics_description_table.csv  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/streamflow_statistics_description_table.csv
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/streamflow_statistics_description_table.csv or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/streamflow_statistics_description_table.csv.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/streamflow_statistics_description_table.csv.ZIP, period.
# Unzipping file:  streamflow_statistics_from_hydrologic_simulations_metadata.xml  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/streamflow_statistics_from_hydrologic_simulations_metadata.xml
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/streamflow_statistics_from_hydrologic_simulations_metadata.xml or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/streamflow_statistics_from_hydrologic_simulations_metadata.xml.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/streamflow_statistics_from_hydrologic_simulations_metadata.xml.ZIP, period.
# Unzipping file:  nhm_hru_id_crosswalk.csv  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/nhm_hru_id_crosswalk.csv
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/nhm_hru_id_crosswalk.csv or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/nhm_hru_id_crosswalk.csv.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/nhm_hru_id_crosswalk.csv.ZIP, period.
# Unzipping file:  nhm_segment_id_crosswalk.csv  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/nhm_segment_id_crosswalk.csv
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/nhm_segment_id_crosswalk.csv or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/nhm_segment_id_crosswalk.csv.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/nhm_segment_id_crosswalk.csv.ZIP, period.
# Unzipping file:  Segments_subset.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/Segments_subset.zip
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/Segments_subset.dbf
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/Segments_subset.prj
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/Segments_subset.shp
#   inflating: /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/Segments_subset.shx
# Unzipping file:  hydrologic_regions_map_USGS.png  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/hydrologic_regions_map_USGS.png
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/hydrologic_regions_map_USGS.png or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/hydrologic_regions_map_USGS.png.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/hydrologic_regions_map_USGS.png.ZIP, period.
# Unzipping file:  GIS_features_used_in_simulations_metadata.xml  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/GIS_features_used_in_simulations_metadata.xml
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/GIS_features_used_in_simulations_metadata.xml or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/GIS_features_used_in_simulations_metadata.xml.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/GIS_features_used_in_simulations_metadata.xml.ZIP, period.

# %% [markdown]
# Finally, let's attempt to unzip the files missing md5 sums and see what happens. Hopefully all downloads were complete and there are no errors.

# %%
for file in md5_missing:
    filepath = str(list(dir.glob(f'**/{file}'))[0])
    output_subdir = list(dir.glob(f'**/{file}'))[0].parent
    print('Unzipping file: ', file, ' into ', output_subdir)
    # !unzip {filepath} -d {output_subdir}
# Out:
# Unzipping file:  dynamic_BNU-ESM_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_BNU-ESM_r1i1p1_diff.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_BNU-ESM_r1i1p1_diff.zip or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_BNU-ESM_r1i1p1_diff.zip.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_BNU-ESM_r1i1p1_diff.zip.ZIP, period.
# Unzipping file:  dynamic_ACCESS1-0_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_ACCESS1-0_r1i1p1.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_ACCESS1-0_r1i1p1.zip or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_ACCESS1-0_r1i1p1.zip.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_ACCESS1-0_r1i1p1.zip.ZIP, period.
# Unzipping file:  dynamic_BNU-ESM_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_BNU-ESM_r1i1p1.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_BNU-ESM_r1i1p1.zip or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_BNU-ESM_r1i1p1.zip.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_BNU-ESM_r1i1p1.zip.ZIP, period.
# Unzipping file:  dynamic_Maurer.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_Maurer.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_Maurer.zip or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_Maurer.zip.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_Maurer.zip.ZIP, period.
# Unzipping file:  dynamic_ACCESS1-0_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_ACCESS1-0_r1i1p1_diff.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_ACCESS1-0_r1i1p1_diff.zip or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_ACCESS1-0_r1i1p1_diff.zip.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_ACCESS1-0_r1i1p1_diff.zip.ZIP, period.
# Unzipping file:  dynamic_bcc-csm1-1_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_bcc-csm1-1_r1i1p1_diff.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_bcc-csm1-1_r1i1p1_diff.zip or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_bcc-csm1-1_r1i1p1_diff.zip.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_bcc-csm1-1_r1i1p1_diff.zip.ZIP, period.
# Unzipping file:  dynamic_bcc-csm1-1_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_bcc-csm1-1_r1i1p1.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_bcc-csm1-1_r1i1p1.zip or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_bcc-csm1-1_r1i1p1.zip.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_bcc-csm1-1_r1i1p1.zip.ZIP, period.
# Unzipping file:  dynamic_CCSM4_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_CCSM4_r1i1p1_diff.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_CCSM4_r1i1p1_diff.zip or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_CCSM4_r1i1p1_diff.zip.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_CCSM4_r1i1p1_diff.zip.ZIP, period.
# Unzipping file:  dynamic_CCSM4_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_CCSM4_r1i1p1.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_CCSM4_r1i1p1.zip or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_CCSM4_r1i1p1.zip.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_CCSM4_r1i1p1.zip.ZIP, period.
# Unzipping file:  dynamic_GFDL-ESM2G_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2G_r1i1p1_diff.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2G_r1i1p1_diff.zip or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2G_r1i1p1_diff.zip.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2G_r1i1p1_diff.zip.ZIP, period.
# Unzipping file:  dynamic_GFDL-ESM2G_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2G_r1i1p1.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2G_r1i1p1.zip or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2G_r1i1p1.zip.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2G_r1i1p1.zip.ZIP, period.
# Unzipping file:  dynamic_GFDL-ESM2M_r1i1p1_diff.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2M_r1i1p1_diff.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2M_r1i1p1_diff.zip or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2M_r1i1p1_diff.zip.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2M_r1i1p1_diff.zip.ZIP, period.
# Unzipping file:  dynamic_GFDL-ESM2M_r1i1p1.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2M_r1i1p1.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2M_r1i1p1.zip or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2M_r1i1p1.zip.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/stats/dynamic_GFDL-ESM2M_r1i1p1.zip.ZIP, period.
# Unzipping file:  HRU_subset.zip  into  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis
# Archive:  /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/HRU_subset.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/HRU_subset.zip or
#         /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/HRU_subset.zip.zip, and cannot find /import/beegfs/CMIP6/jdpaul3/hydroviz_data/gis/HRU_subset.zip.ZIP, period.

# %% [markdown]
# Well that's annoying! We need to find out what's going on with these files and why they won't unzip!
